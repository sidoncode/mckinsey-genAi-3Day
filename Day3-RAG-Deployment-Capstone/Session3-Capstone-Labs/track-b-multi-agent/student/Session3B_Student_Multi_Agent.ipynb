# %% [markdown]
# # Session 3 — Track B: McKinsey Multi-Agent Engagement Team (Student Capstone)
#
# In this capstone, you will build a **multi-agent consulting engagement system** that decomposes complex client questions, delegates workstreams to specialized consulting agents, and orchestrates their collaboration — mirroring how a McKinsey engagement team tackles real client problems. You will integrate everything from Days 1-3: LLM APIs, tool use, LangGraph workflows, and agent patterns.
#
# Work through the milestones in order. Each milestone builds on the previous one. Prepare a **2-minute demo** for Session 4.
#
# **Engagement Scenario:** A Private Equity client is evaluating an acquisition target in the healthcare technology space. Your engagement team must deliver a comprehensive due diligence assessment covering market dynamics, financial performance, competitive positioning, and operational readiness.

# %% [markdown]
# ## Capstone Objectives
#
# By the end of this capstone, you will have built:
#
# 1. An **Engagement Manager (supervisor) agent** that decomposes client questions into workstreams and assigns them to the right specialists
# 2. **Specialized consulting agents** — Strategy Analyst, Financial Analyst, Operations Expert, and Industry Researcher — each with distinct analytical capabilities
# 3. A **LangGraph orchestration** layer managing workstream coordination, dependency sequencing, and insight synthesis
# 4. An **evaluation and self-correction** loop ensuring deliverable quality meets McKinsey standards (Partner Review)
#
# This mirrors the structure of a real McKinsey engagement: a Partner or EM coordinates workstreams, specialized analysts execute their workstreams, and the team synthesizes findings into a unified recommendation.

# %%
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env

# LangSmith tracing configuration
os.environ["LANGCHAIN_TRACING_V2"] = os.getenv("LANGCHAIN_TRACING_V2", "false")
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT", "mckinsey-genai-3day")

# ============================================================
# Imports and Setup
# ============================================================

import openai
import json
import time
from typing import TypedDict, Annotated, List, Dict, Optional
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.tools import tool
from langgraph.graph import StateGraph, END
import operator

print("All imports successful!")

# %% [markdown]
# ---
# ## Milestone 1: Engagement Manager Agent & Workstream Decomposition
#
# Build an Engagement Manager agent that takes a complex client question, breaks it into workstreams (each with a hypothesis to test), and decides which consulting specialist should handle each one.
#
# **Requirements:**
# - Accept a complex client question (e.g., PE due diligence, market entry, digital transformation)
# - Decompose into 2-4 workstreams with clear hypotheses and descriptions
# - Assign each workstream to a specialist type (strategy_analyst, financial_analyst, operations_expert, industry_researcher)
# - Return a structured engagement plan as JSON

# %%
# Milestone 1 - Engagement Manager Agent & Workstream Decomposition

# TODO: Build an EngagementManagerAgent class that:
# 1. Takes a complex client question (PE due diligence, market entry, etc.)
# 2. Decomposes it into 2-4 workstreams using the LLM
# 3. Assigns each workstream to a consulting specialist
# 4. Returns a structured engagement plan
#
# Hint: Prompt the LLM to return JSON with workstreams and specialist assignments
# Hint: Available specialists: strategy_analyst, financial_analyst, operations_expert, industry_researcher
# Hint: Each workstream needs: id, description, hypothesis, assigned_specialist, dependencies
# Hint: Use consulting language in the system prompt — "hypotheses", "workstreams", "engagement team"

class EngagementManagerAgent:
    def __init__(self):
        # YOUR CODE HERE
        pass

    def decompose(self, client_question: str) -> Dict:
        """Decompose a client question into workstreams with specialist assignments."""
        # YOUR CODE HERE
        pass


# Test — PE Due Diligence scenario
# em = EngagementManagerAgent()
# plan = em.decompose(
#     "Our PE client is considering acquiring a mid-market healthcare IT company. "
#     "Assess the target's market position, financial health, operational scalability, "
#     "and provide a go/no-go recommendation with key risks and value creation levers."
# )
# print(json.dumps(plan, indent=2))

# %% [markdown]
# ---
# ## Milestone 2: Specialized Consulting Agents
#
# Build specialized consulting agents, each representing a key role on a McKinsey engagement team. Each specialist should have a unique system prompt that defines their analytical expertise and output format.
#
# **Requirements:**
# - **Strategy Analyst:** Market sizing, competitive analysis, Porter's Five Forces, strategic positioning
# - **Financial Analyst:** Revenue/cost decomposition, margin analysis, valuation frameworks, ROI modeling
# - **Operations Expert:** Operating model assessment, scalability evaluation, process efficiency, implementation roadmaps
# - **Industry Researcher:** Market trends, regulatory landscape, technology disruptions, forward-looking perspectives

# %%
# Milestone 2 - Specialized Consulting Agents

# TODO: Build consulting specialist agent classes that:
# 1. Each has a McKinsey-style system prompt defining their expertise and analytical frameworks
# 2. Accept a workstream description and context from other completed workstreams
# 3. Execute the workstream using the LLM
# 4. Return structured output with result and metadata
#
# Hint: Each specialist gets context from completed workstreams (cross-workstream insight sharing)
# Hint: Return {"result": str, "worker": str} where worker is the specialist type
# Hint: Use consulting language in system prompts: hypotheses, implications, so-whats, recommendations
# Hint: Strategy Analyst should reference frameworks like Porter's Five Forces, value chain analysis
# Hint: Financial Analyst should quantify everything and use ranges where exact figures are unavailable

class StrategyAnalystAgent:
    def __init__(self):
        # YOUR CODE HERE
        pass
    
    def execute(self, workstream, context=""):
        # YOUR CODE HERE
        pass

class FinancialAnalystAgent:
    def __init__(self):
        # YOUR CODE HERE
        pass
    
    def execute(self, workstream, context=""):
        # YOUR CODE HERE
        pass

class OperationsExpertAgent:
    def __init__(self):
        # YOUR CODE HERE
        pass
    
    def execute(self, workstream, context=""):
        # YOUR CODE HERE
        pass

class IndustryResearcherAgent:
    def __init__(self):
        # YOUR CODE HERE
        pass
    
    def execute(self, workstream, context=""):
        # YOUR CODE HERE
        pass


# Test — Strategy Analyst on a competitive analysis workstream
# strategy_analyst = StrategyAnalystAgent()
# result = strategy_analyst.execute(
#     "Assess the competitive positioning of the target healthcare IT company. "
#     "Identify top 3-5 competitors, relative market share, and key differentiators."
# )
# print(f"Specialist: {result['worker']}")
# print(f"Analysis (preview): {result['result'][:400]}...")

# %% [markdown]
# ---
# ## Milestone 3: LangGraph Engagement Orchestration
#
# Build a LangGraph workflow that orchestrates the Engagement Manager and consulting specialists into a coordinated engagement team. The graph should manage state, handle dependencies between workstreams, and route work to the correct specialists.
#
# **Requirements:**
# - Define a state schema that tracks the engagement plan, completed workstreams, and final deliverable
# - Engagement Manager node creates the workstream plan
# - Specialist nodes execute workstreams in dependency order
# - Conditional routing to the correct specialist based on workstream assignment
# - Synthesis node combines all workstream insights into a unified client deliverable

# %%
# Milestone 3 - LangGraph Engagement Orchestration

# TODO: Build a LangGraph StateGraph that:
# 1. Defines state: client_question, plan, completed_workstreams, current_workstream_idx, deliverable
# 2. Has an Engagement Manager node that creates the workstream plan
# 3. Has a dispatcher node that picks the next workstream and routes to the right specialist
# 4. Has specialist nodes for each consulting agent type
# 5. Has a synthesis node that combines all workstream outputs into a client deliverable
# 6. Loops until all workstreams are complete
#
# Hint: Use conditional edges to route from dispatcher to the correct specialist
# Hint: After each specialist completes, return to dispatcher to check for more workstreams
# Hint: When all workstreams done, route to synthesis then END
# Hint: Build context from completed workstreams so specialists can see each other's insights

class EngagementState(TypedDict):
    client_question: str
    plan: Dict
    completed_workstreams: List[Dict]
    current_workstream_idx: int
    deliverable: str

# YOUR CODE HERE: Define nodes (em_node, dispatcher_node, specialist_node, synthesis_node)
# YOUR CODE HERE: Define routing function (route_dispatcher)
# YOUR CODE HERE: Build the StateGraph with edges


# Test — Market entry strategy engagement
# result = engagement_app.invoke({
#     "client_question": (
#         "A Fortune 500 industrial company wants to enter the Southeast Asian market "
#         "for smart manufacturing solutions. Assess market attractiveness, competitive "
#         "landscape, financial feasibility, and recommend an entry strategy."
#     ),
#     "plan": {}, "completed_workstreams": [], "current_workstream_idx": 0, "deliverable": ""
# })
# print(f"Completed {len(result['completed_workstreams'])} workstreams")
# print(f"\nClient deliverable preview:\n{result['deliverable'][:500]}...")

# %% [markdown]
# ---
# ## Milestone 4: Partner Review & Quality Assurance Loop
#
# Add a Partner-level quality review and self-correction loop to ensure deliverables meet McKinsey standards before going to the client.
#
# **Requirements:**
# - Evaluate the final deliverable on three dimensions: analytical rigor, actionability of recommendations, and strategic coherence
# - If average quality score < 3.5 (out of 5), identify the weakest area and trigger revision
# - Limit retries to max 2 revision cycles (just like real engagement timelines)
# - Track improvement across iterations to demonstrate the quality loop's value

# %%
# Milestone 4 - Partner Review & Quality Assurance Loop

# TODO: Add Partner review and self-correction:
# 1. Create an EnhancedEngagementState with additional fields: scores, revision_count
# 2. Build a partner_review_node that evaluates the deliverable on:
#    - analytical_rigor (1-5): Are hypotheses clear with supporting evidence?
#    - actionability (1-5): Could a CEO act on these recommendations immediately?
#    - strategic_coherence (1-5): Do workstream outputs tell a unified story?
# 3. Build a revision_node that identifies the weakest dimension and rewrites
# 4. If avg score < 3.5 and revision_count < 2, route to reviser; otherwise END
# 5. Track scores across iterations
#
# Hint: Add partner_review and reviser nodes to the enhanced graph
# Hint: Use conditional edge: score >= threshold -> END, else -> reviser
# Hint: The reviser should use McKinsey structure: situation, complication, resolution
# Hint: Connect synthesis -> partner_review -> (reviser or END)

# YOUR CODE HERE


# Test — Full PE due diligence engagement with Partner review
# result = enhanced_engagement_app.invoke({
#     "client_question": (
#         "Our PE client is evaluating a $500M acquisition of a healthcare IT platform company. "
#         "Conduct a comprehensive due diligence covering market dynamics, competitive positioning, "
#         "financial health, and operational scalability. Provide a go/no-go recommendation "
#         "with key risks, value creation levers, and a 100-day integration plan."
#     ),
#     "plan": {}, "completed_workstreams": [], "current_workstream_idx": 0,
#     "deliverable": "", "scores": [], "revision_count": 0
# })
# print(f"\nCompleted {len(result['completed_workstreams'])} workstreams, {result['revision_count']} revisions")
# print(f"Partner review scores: {[s['average'] for s in result['scores']]}")
# print(f"\nFinal client deliverable:\n{result['deliverable'][:600]}...")

# %% [markdown]
# ---
# ## Capstone Summary
#
# You have built a **McKinsey Multi-Agent Engagement Team** — a production-ready multi-agent system modeled after real consulting engagement structure:
#
# 1. **Engagement Manager (Supervisor)** -- Decomposes client questions into workstreams with hypotheses, assigns specialists, and manages dependencies
# 2. **Consulting Specialists (Workers)** -- Strategy Analyst, Financial Analyst, Operations Expert, and Industry Researcher — each with domain-specific analytical frameworks
# 3. **Engagement Orchestration** -- LangGraph workflow with conditional routing, cross-workstream context sharing, and deliverable synthesis
# 4. **Partner Review (Self-Correction)** -- Quality evaluation on analytical rigor, actionability, and strategic coherence — with automated revision until McKinsey standards are met
#
# Prepare a **2-minute demo** for Session 4. Focus on showing the engagement team collaboration, cross-workstream insight sharing, and the Partner review quality loop in action.
#
# **Up Next:** Session 4 -- Cross-track presentations, AI governance, and closing.
