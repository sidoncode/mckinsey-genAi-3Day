# %% [markdown]
# # Session 3 — Track B: Multi-Agent Orchestration (Student Capstone)
#
# In this capstone, you will build a **multi-agent system** that decomposes complex tasks, delegates to specialized worker agents, and orchestrates their collaboration. You will integrate everything from Days 1-3: LLM APIs, tool use, LangGraph workflows, and agent patterns.
#
# Work through the milestones in order. Each milestone builds on the previous one. Prepare a **2-minute demo** for Session 4.

# %% [markdown]
# ## Capstone Objectives
#
# By the end of this capstone, you will have built:
#
# 1. A **supervisor agent** that decomposes tasks and routes to workers
# 2. **Specialized worker agents** with distinct tools and capabilities
# 3. A **LangGraph orchestration** layer managing agent collaboration
# 4. An **evaluation and self-correction** loop for quality assurance

# %%
# ============================================================
# Imports and Setup
# ============================================================

import openai
import json
import time
from typing import TypedDict, Annotated, List, Dict, Optional
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.tools import tool
from langgraph.graph import StateGraph, END
import operator

print("All imports successful!")

# %% [markdown]
# ---
# ## Milestone 1: Supervisor Agent & Task Decomposition
#
# Build a supervisor agent that takes a complex user request, breaks it into subtasks, and decides which worker should handle each subtask.
#
# **Requirements:**
# - Accept a complex user request
# - Decompose into 2-4 subtasks with clear descriptions
# - Assign each subtask to a worker type (researcher, writer, coder, reviewer)
# - Return a structured plan as JSON

# %%
# Milestone 1 - Supervisor Agent & Task Decomposition

# TODO: Build a SupervisorAgent class that:
# 1. Takes a complex user request
# 2. Decomposes it into subtasks using the LLM
# 3. Assigns each subtask to a worker type
# 4. Returns a structured plan
#
# Hint: Prompt the LLM to return JSON with subtasks and assignments
# Hint: Available workers: researcher, writer, coder, reviewer
# Hint: Each subtask needs: id, description, assigned_worker, dependencies

class SupervisorAgent:
    def __init__(self):
        # YOUR CODE HERE
        pass

    def decompose(self, request: str) -> Dict:
        """Decompose a request into subtasks with worker assignments."""
        # YOUR CODE HERE
        pass


# Test
# supervisor = SupervisorAgent()
# plan = supervisor.decompose("Write a technical blog post about RAG with code examples")
# print(json.dumps(plan, indent=2))

# %% [markdown]
# ---
# ## Milestone 2: Specialized Worker Agents with Tools
#
# Build specialized worker agents, each with unique tools and capabilities. Workers should execute their assigned subtask and return structured results.
#
# **Requirements:**
# - Researcher: searches and summarizes information
# - Writer: creates content from outlines or research
# - Coder: writes and explains code snippets
# - Reviewer: evaluates quality and suggests improvements

# %%
# Milestone 2 - Specialized Worker Agents

# TODO: Build worker agent classes that:
# 1. Each has a specialized system prompt and tools
# 2. Accept a subtask description and context from previous workers
# 3. Execute the subtask using LLM + tools
# 4. Return structured output with result and metadata
#
# Hint: Use @tool decorator for worker-specific tools
# Hint: Each worker gets context from completed subtasks
# Hint: Return {result: str, worker: str, tokens_used: int}

class ResearcherAgent:
    def __init__(self):
        # YOUR CODE HERE
        pass
    
    def execute(self, subtask, context=""):
        # YOUR CODE HERE
        pass

class WriterAgent:
    def __init__(self):
        # YOUR CODE HERE
        pass
    
    def execute(self, subtask, context=""):
        # YOUR CODE HERE
        pass

class CoderAgent:
    def __init__(self):
        # YOUR CODE HERE
        pass
    
    def execute(self, subtask, context=""):
        # YOUR CODE HERE
        pass

class ReviewerAgent:
    def __init__(self):
        # YOUR CODE HERE
        pass
    
    def execute(self, subtask, context=""):
        # YOUR CODE HERE
        pass


# Test
# researcher = ResearcherAgent()
# result = researcher.execute("Research the key components of a RAG pipeline")
# print(result)

# %% [markdown]
# ---
# ## Milestone 3: LangGraph Orchestration
#
# Build a LangGraph workflow that orchestrates the supervisor and workers. The graph should manage state, handle dependencies between subtasks, and route work to the correct agents.
#
# **Requirements:**
# - Define a state schema that tracks the plan, completed tasks, and final output
# - Supervisor node creates the plan
# - Worker nodes execute subtasks in dependency order
# - Conditional routing to the correct worker based on assignment

# %%
# Milestone 3 - LangGraph Orchestration

# TODO: Build a LangGraph StateGraph that:
# 1. Defines state: request, plan, completed_tasks, current_task_idx, output
# 2. Has a supervisor node that creates the plan
# 3. Has a dispatcher node that picks the next task and routes to the right worker
# 4. Has worker nodes for each agent type
# 5. Loops until all tasks are complete
#
# Hint: Use conditional edges to route from dispatcher to the correct worker
# Hint: After each worker, return to dispatcher to check for more tasks
# Hint: When all tasks done, route to END

class AgentState(TypedDict):
    request: str
    plan: Dict
    completed_tasks: List[Dict]
    current_task_idx: int
    output: str

# YOUR CODE HERE: Define nodes and build the graph


# Test
# result = graph.invoke({"request": "Write a blog post about RAG with code examples"})
# print(result["output"])

# %% [markdown]
# ---
# ## Milestone 4: Evaluation & Self-Correction Loop
#
# Add an evaluation step that checks the quality of the combined output and triggers self-correction if the quality is below threshold.
#
# **Requirements:**
# - Evaluate the final output on completeness, coherence, and accuracy
# - If quality score < threshold, identify specific issues and trigger revision
# - Limit retries to prevent infinite loops
# - Track improvement across iterations

# %%
# Milestone 4 - Evaluation & Self-Correction

# TODO: Add evaluation and self-correction:
# 1. Evaluate the final output (completeness, coherence, accuracy) 1-5 each
# 2. If avg score < 3.5, identify issues and revise
# 3. Limit to max 2 revision cycles
# 4. Track scores across iterations
#
# Hint: Add an evaluator node to the graph
# Hint: Use conditional edge: score >= threshold -> END, else -> reviser
# Hint: Reviser node takes feedback and improves the output

# YOUR CODE HERE


# Test
# result = enhanced_graph.invoke({"request": "Write a blog post about RAG"})
# print(f"Final output: {result['output'][:200]}...")
# print(f"Quality scores: {result['scores']}")

# %% [markdown]
# ---
# ## Capstone Summary
#
# You have built a **multi-agent orchestration system** with:
#
# 1. **Supervisor** -- Task decomposition and worker assignment
# 2. **Workers** -- Specialized agents (researcher, writer, coder, reviewer)
# 3. **Orchestration** -- LangGraph workflow with conditional routing
# 4. **Self-Correction** -- Quality evaluation with automated revision
#
# Prepare a **2-minute demo** for Session 4. Focus on showing the agent collaboration and self-correction in action.
#
# **Up Next:** Session 4 — Cross-track presentations, governance, and closing.
